# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#                                              comment        type
# 0                                       يعطيكم الصحة      normal
# 1                                    عشي عندهما رجال      normal
# 2                         نبيك مغتصب الاطفال المنيوك  aggressive
# 3  بشير فار حبس خارج ثالثة ابتيدائي جاي اتناقش ما...      normal
# 4  مول القناة دزيزي جنيت تفرجت الفديو تاعك ولدي ت...      normal

# %%
process = df["comment"]
process
# Out:
# 0                                            يعطيكم الصحة
# 1                                         عشي عندهما رجال
# 2                              نبيك مغتصب الاطفال المنيوك
# 3       بشير فار حبس خارج ثالثة ابتيدائي جاي اتناقش ما...
# 4       مول القناة دزيزي جنيت تفرجت الفديو تاعك ولدي ت...
#                               ...
# 4401    مممتلكت مممتلكت تتحدثون عاليه مرتن تقول ايمام ...
# 4402                   ربي يلعنو رئيس تونس الخنزير بففففف
# 4403    قولك اننا لسنا عرب ههههه اذهبي للمخبر حليلي جي...
# 4404    علاقة للتحرش باللباس الدول لتي تبيح الحرية الج...
# 4405                           لطفي العبدلي خير ألحق بارك
# Name: comment, Length: 4406, dtype: object

# %%
df.isnull().sum()
# Out:
# comment       0
# type          0
# aggressive    0
# dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer 

v = CountVectorizer(ngram_range=(3, 3))
v.fit(process)
v.vocabulary_
# Out:
# {'عشي عندهما رجال': 18388,
#  'نبيك مغتصب الاطفال': 24941,
#  'مغتصب الاطفال المنيوك': 24149,
#  'بشير فار حبس': 9293,
#  'فار حبس خارج': 19079,
#  'حبس خارج ثالثة': 13376,
#  'خارج ثالثة ابتيدائي': 13996,
#  'ثالثة ابتيدائي جاي': 12630,
#  'ابتيدائي جاي اتناقش': 813,
#  'جاي اتناقش مايا': 12817,
#  'اتناقش مايا عيب': 938,
#  'مايا عيب اعليك': 22608,
#  'عيب اعليك جاهل': 18877,
#  'اعليك جاهل مالقيتهاش': 1616,
#  'جاهل مالقيتهاش ومانجمتش': 12783,
#  'مالقيتهاش ومانجمتش تناقش': 22483,
#  'ومانجمتش تناقش جاهل': 28490,
#  'تناقش جاهل دورتها': 11892,
#  'جاهل دورتها تهريج': 12779,
#  'دورتها تهريج ااجاهل': 14702,
#  'تهريج ااجاهل عبدلي': 11989,
#  'ااجاهل عبدلي وقتلي': 783,
#  'عبدلي وقتلي عصراتو': 18195,
#  'وقتلي عصراتو مايا': 28130,
#  'عصراتو مايا قالها': 18424,
#  'مايا قالها بايرة': 22612,
#  'قالها بايرة والجمهور': 19772,
#  'بايرة والجمهور العظيم': 8835,
#  'والجمهور العظيم جمهور': 26673,
#  'العظيم جمهور كسكروتات': 5446,
#  'جمهور كسكروتات قحاب': 13053,
#  'كسكروتات قحاب وطحانة': 20667,
#  'قحاب وطحانة اهانة': 19913,
#  'وطحانة اهانة لاي': 27974,
#  'اهانة لاي مثقف': 8148,
#  'لاي مثقف اضحكهم': 21184,
#  'مثقف اضحكهم تعرف': 22959,
#  'اضحكهم تعرف مستواهم': 1535,
#  'تعرف مستواهم اطايح': 11279,
#  'مستواهم اطايح زميمهم': 23632,
#  'اطايح زميمهم سامي': 1541,
#  'زميمهم سامي الفهري': 16115,
#  'سامي الفهري يعشق': 16270,
#  'الفهري يعشق الابتذال': 5834,
#  'مول القناة دزيزي': 24704,
#  'القناة دزيزي جنيت': 6118,
#  'دزيزي جنيت تفرجت': 14611,
#  'جنيت تفرجت الفديو': 13078,
#  'تفرجت الفديو تاعك': 11467,
#  'الفديو تاعك ولدي': 5744,
#  'تاعك ولدي تعرفو': 10057,
#  'ولدي تعرفو خير': 28372,
#  'تعرفو خير ربي': 11291,
#  'خير ربي سبحانو': 14410,
#  'ربي سبحانو عطاك': 15340,
#  'سبحانو عطاك شرف': 16326,
#  'عطاك شرف الجود': 18435,
#  'شرف الجود تونس': 16858,
#  'الجود تونس لازمها': 3384,
#  'تونس لازمها فتوحات': 12370,
#  'لازمها فتوحات اسلامية': 21116,
#  'فتوحات اسلامية الاحترام': 19249,
#  'اسلامية الاحترام لانو': 1400,
#  'الاحترام لانو صحاب': 2201,
#  'لانو صحاب توانسا': 21170,
#  'الحرب الإسلام والمسلمين': 3477,
#  'الإسلام والمسلمين وصلت': 2091,
#  'والمسلمين وصلت ديار': 27095,
#  'وصلت ديار القيروان': 27930,
#  'ديار القيروان بالله': 14800,
#  'القيروان بالله اللهم': 6159,
#  'بالله اللهم دمر': 8675,
#  'اللهم دمر الكفار': 6414,
#  'دمر الكفار والمنافقين': 14667,
#  'الكفار والمنافقين بلاد': 6255,
#  'والمنافقين بلاد الإسلام': 27117,
#  'بلاد الإسلام العالم': 9515,
#  'الإسلام العالم اينعت': 2047,
#  'العالم اينعت رؤوس': 5186,
#  'اينعت رؤوس الظالمين': 8279,
#  'رؤوس الظالمين تونس': 15023,
#  'الظالمين تونس الإسلام': 5136,
#  'تونس الإسلام لاشيء': 12131,
#  'رجال تونس اعطيوتو': 15502,
#  'تونس اعطيوتو المراة': 12123,
#  'اعطيوتو المراة حقها': 1603,
#  'المراة حقها اصبحت': 6741,
#  'حقها اصبحت تتطاول': 13720,
#  'اصبحت تتطاول اخ': 1497,
#  'تتطاول اخ الجزائر': 10250,
#  'تحيا كريم الغربي': 10626,
#  'كريم الغربي ونقول': 20646,
#  'الغربي ونقول للمعزة': 5654,
#  'ونقول للمعزة مايا': 28695,
#  'للمعزة مايا برشيني': 21992,
#  'مايا برشيني اشتحميني': 22588,
#  'برشيني اشتحميني ههه': 9113,
#  'تونس الكافر والمسلم': 12170,
#  'الكافر والمسلم مسلمين': 6173,
#  'والمسلم مسلمين وأغلبهم': 27090,
#  'مسلمين وأغلبهم كفار': 23784,
#  'وأغلبهم كفار معاش': 26391,
#  'كفار معاش نغطو': 20688,
#  'معاش نغطو الشمس': 23972,
#  'نغطو الشمس بالغربال': 25528,
#  'الشمس بالغربال المسلمين': 4934,
#  'بالغربال المسلمين قلة': 8601,
#  'المسلمين قلة تونس': 6918,
#  'قلة تونس أسلمت': 20182,
#  'تونس أسلمت الشعب': 12106,
#  'أسلمت الشعب منهج': 229,
#  'الشعب منهج يمت': 4890,
#  'منهج يمت للإسلام': 24563,
#  'يمت للإسلام بصلة': 30550,
#  'تحياتنا كريم الغربي': 10630,
#  'كريم الغربي زملاؤه': 20644,
#  'الغربي زملاؤه أخلاق': 5649,
#  'زملاؤه أخلاق المسلم': 16107,
#  'أخلاق المسلم حاجتو': 150,
#  'المسلم حاجتو لاااازم': 6871,
#  'حاجتو لاااازم دائما': 13277,
#  'لاااازم دائما وأبدااا': 21044,
#  'دائما وأبدااا مايغيرش': 14448,
#  'وأبدااا مايغيرش التعاليم': 26354,
#  'مايغيرش التعاليم الإسلامية': 22676,
#  'التعاليم الإسلامية ويبقى': 2875,
#  'الإسلامية ويبقى يدافع': 2121,
#  'ويبقى يدافع دينه': 28771,
#  'يدافع دينه زمان': 29665,
#  'دينه زمان ومكان': 14910,
#  'زمان ومكان واخلاق': 16102,
#  'ومكان واخلاق ربي': 28579,
#  'واخلاق ربي يهديهم': 26483,
#  'ربي يهديهم ويهدينا': 15474,
#  'يهديهم ويهدينا تشدد': 30736,
#  'ويهدينا تشدد لالة': 28897,
#  'تشدد لالة منهرفش': 11023,
#  'لالة منهرفش سمك': 21142,
#  'منهرفش سمك دينا': 24567,
#  'سمك دينا العظيم': 16524,
#  'دينا العظيم قاعدة': 14878,
#  'العظيم قاعدة تهاجمي': 5452,
#  'قاعدة تهاجمي كأمة': 19717,
#  'تهاجمي كأمة واحدة': 11974,
#  'كسكسي شعير خفيف': 20668,
#  'شعير خفيف ويعمل': 17022,
#  'خفيف ويعمل الكيف': 14222,
#  'مريام الدباغ معرسه': 23438,
#  'الدباغ معرسه معرسه': 3842,
#  'تونس بلاد قحب': 12212,
#  'داخلة بالمعرفة اللقيطة': 14461,
#  'بالمعرفة اللقيطة القصوري': 8737,
#  'اللقيطة القصوري الماخور': 6400,
#  'القصوري الماخور التونسي': 6086,
#  'سميسو قحية كبيرة': 16527,
#  'قحية كبيرة ولطفي': 19977,
#  'كبيرة ولطفي اقحب': 20503,
#  'الشاب بشر منيك': 4716,
#  'بشر منيك سحيح': 9218,
#  'منيك سحيح وحل': 24578,
#  'سحيح وحل صحيح': 16376,
#  'وحل صحيح ميقدرش': 27634,
#  'صحيح ميقدرش والمراةاذا': 17433,
#  'ميقدرش والمراةاذا فاحت': 24799,
#  'والمراةاذا فاحت راءيحته': 27079,
#  'فاحت راءيحته خارج': 19075,
#  'راءيحته خارج منزله': 15048,
#  'خارج منزله تعتبر': 13997,
#  'منزله تعتبر زانية': 24510,
#  'تعتبر زانية فمابالك': 11217,
#  'زانية فمابالك صوته': 15978,
#  'خاف رب باجي': 14023,
#  'رب باجي رجل': 15250,
#  'باجي رجل القبر': 8343,
#  'رجل القبر ورجل': 15550,
#  'القبر ورجل الدنيا': 5904,
#  'ورجل الدنيا شعب': 27759,
#  'الدنيا شعب مسلم': 3927,
#  'شعب مسلم وانتبعوا': 16979,
#  'مسلم وانتبعوا حكم': 23730,
#  'وانتبعوا حكم رب': 27191,
#  'حكم رب حكمك': 13793,
#  'تربحك كلبه وسبسي': 10778,
#  'كلبه وسبسي مسؤل': 20868,
#  'وسبسي مسؤل حكومت': 27812,
#  'مسؤل حكومت سبسي': 23549,
#  'شميس غالي متربي': 17172,
#  'غالي متربي لطفي': 18947,
#  'متربي لطفي نحبك': 22835,
#  'لطفي نحبك طلعت': 21572,
#  'نحبك طلعت كعبة': 25083,
#  'طلعت كعبة اخلاقيا': 17891,
#  'كعبة اخلاقيا زينة': 20678,
#  'اخلاقيا زينة الراجل': 1163,
#  'زينة الراجل اخلاقو': 16195,
#  'الراجل اخلاقو فعلو': 4164,
#  'شك كبير تنسحب': 17053,
#  'كبير تنسحب قناة': 20476,
#  'تنسحب قناة متعدت': 11930,
#  'قناة متعدت حدودها': 20267,
#  'عللخر عمبو الفلوس': 18558,
#  'عمبو الفلوس خلت': 18624,
#  'الفلوس خلت العباد': 5817,
#  'خلت العباد تعصي': 14240,
#  'العباد تعصي كلام': 5246,
#  'تعصي كلام ربي': 11305,
#  'كلام ربي ولي': 20765,
#  'ربي ولي الباجي': 15399,
#  'ولي الباجي يحكي': 28430,
#  'الباجي يحكي حاجة': 2588,
#  'يحكي حاجة فالدين': 29536,
#  'حاجة فالدين ومهما': 13255,
#  'فالدين ومهما المشكلة': 19142,
#  'ومهما المشكلة عمرنا': 28600,
#  'المشكلة عمرنا مانعصو': 6987,
#  'عمرنا مانعصو ربي': 18647,
#  'مانعصو ربي ونعارضوا': 22520,
#  'ربي ونعارضوا أية': 15401,
#  'ونعارضوا أية واضحة': 28667,
#  'أية واضحة عللخر': 623,
#  'واضحة عللخر ومفهومة': 26534,
#  'عللخر ومفهومة حسبي': 18559,
#  'ومفهومة حسبي ونعم': 28576,
#  'حسبي ونعم الوكيل': 13591,
#  'تكفيري قح العياذ': 11742,
#  'قح العياذ بالله': 19895,
#  'العياذ بالله وجود': 5580,
#  'بالله وجود للسلفية': 8708,
#  'وجود للسلفية الجهادية': 27562,
#  'للسلفية الجهادية العلمية': 21902,
#  'الجهادية العلمية غيرهما': 3359,
#  'العلمية غيرهما السلفية': 5524,
#  'غيرهما السلفية هدي': 19039,
#  'السلفية هدي النبي': 4614,
#  'هدي النبي صلى': 26055,
#  'النبي صلى وسلم': 7440,
#  'صلى وسلم خربتم': 17584,
#  'وسلم خربتم ديننا': 27831,
#  'خربتم ديننا بارك': 14126,
#  'ههههه والله رجل': 26204,
#  'الشاب عبدو مات': 4732,
#  'استغفر لله العظيم': 1358,
#  'لله العظيم ربي': 22010,
#  'العظيم ربي يهزهكم': 5449,
#  'ربي يهزهكم هزاااااااا': 15475,
#  'يهزهكم هزاااااااا رجعة': 30744,
#  'هزاااااااا رجعة مسخين': 26089,
#  'رجعة مسخين اتفوه': 15537,
#  'مسخين اتفوه الكفر': 23667,
#  'تونس بلد الشواذ': 12218,
#  'بلد الشواذ التخلف': 9668,
#  'الشواذ التخلف الرديلة': 4942,
#  'كريم الغربي راجل': 20643,
#  'الغربي راجل نص': 5648,
#  'راجل نص العطايين': 15107,
#  'نص العطايين النقوشة': 25359,
#  'جيت لتونس مرات': 13180,
#  'لتونس مرات بلاد': 21285,
#  'مرات بلاد معبيا': 23333,
#  'بلاد معبيا قحاب': 9567,
#  'معبيا قحاب مكان': 23982,
#  'قحاب مكان وناس': 19909,
#  'مكان وناس تفطر': 24279,
#  'وناس تفطر رمضان': 28621,
#  'تفطر رمضان وحتي': 11488,
#  'رمضان وحتي صوت': 15767,
#  'وحتي صوت الأذان': 27592,
#  'صوت الأذان مانسمعش': 17614,
#  'الأذان مانسمعش بنسبه': 1893,
#  'مانسمعش بنسبه لتونس': 22514,
#  'بنسبه لتونس العاصمة': 9820,
#  'لتونس العاصمة المسلمين': 21277,
#  'العاصمة المسلمين دولة': 5165,
#  'المسلمين دولة كافره': 6906,
#  'دولة كافره تلقا': 14761,
#  'كافره تلقا نسبة': 20416,
#  'تلقا نسبة اسلام': 11790,
#  'نسبة اسلام أكثرية': 25292,
#  'اسلام أكثرية الشعب': 1387,
#  'أكثرية الشعب ديوث': 417,
#  'الشعب ديوث اخلاقه': 4880,
#  'ديوث اخلاقه فاسدة': 14928,
#  'اخلاقه فاسدة ويقولك': 1156,
#  'فاسدة ويقولك مثقف': 19093,
#  'ويقولك مثقف يلعن': 28871,
#  'مثقف يلعن الثقافة': 22968,
#  'ملاهط القحبة تهزوا': 24324,
#  'القحبة تهزوا الحبس': 5956,
#  'تهزوا الحبس اقحاب': 11991,
#  'الحبس اقحاب يمسخوا': 3422,
#  'اقحاب يمسخوا صمعة': 1743,
#  'يمسخوا صمعة تونس': 30573,
#  'صمعة تونس عص': 17597,
#  'تونس عص التونسي': 12334,
#  'عص التونسي معروف': 18391,
#  'التونسي معروف العالم': 3053,
#  'عظم اجركم وربي': 18451,
#  'اجركم وربي يصبر': 962,
#  'وربي يصبر اهلهم': 27751,
#  'لليبية قوتشية أدري': 22050,
#  'قوتشية أدري أنكي': 20313,
#  'أدري أنكي فتاة': 176,
#  'أنكي فتاة أشتم': 548,
#  'فتاة أشتم الفتيات': 19217,
#  'أشتم الفتيات أعتذر': 249,
#  'الفتيات أعتذر سأقوم': 5741,
#  'أعتذر سأقوم بمسح': 296,
#  'سأقوم بمسح كلامي': 16203,
#  'بمسح كلامي ثانيا': 9753,
#  'كلامي ثانيا أظنكي': 20831,
#  'ثانيا أظنكي أمامي': 12631,
#  'أظنكي أمامي لتحدثتي': 293,
#  'أمامي لتحدثتي هكذا': 440,
#  'نصدق ولاد معرسة': 25369,
#  'ولاد معرسة ضاهرلي': 28247,
#  'الأخوة الجزائريين ينصحون': 1889,
#  'الجزائريين ينصحون بطرد': 3287,
#  'ينصحون بطرد لليهود': 30649,
#  'الأميرة القرطاجية ربي': 1991,
#  'القرطاجية ربي يحشرك': 6068,
#  'ربي يحشرك الجحيم': 15412,
#  'يحشرك الجحيم حمالة': 29488,
#  'الجحيم حمالة الحطب': 3180,
#  'حمالة الحطب حطب': 13868,
#  'الحطب حطب جهنم': 3531,
#  'حطب جهنم بالك': 13644,
#  'جهنم بالك الجنة': 13123,
#  'بالك الجنة بالمجان': 8630,
#  'الجنة بالمجان ههههه': 3326,
#  'بالمجان ههههه روحي': 8721,
#  'ههههه روحي تعهري': 26196,
#  'روحي تعهري وقولي': 15917,
#  'تعهري وقولي ربي': 11392,
#  'وقولي ربي يدخلني': 28172,
#  'ربي يدخلني للجنة': 15423,
#  'يدخلني للجنة اتعراي': 29680,
#  'للجنة اتعراي وقولي': 21852,
#  'اتعراي وقولي ربي': 902,
#  'يدخلني للجنة نهار': 29681,
#  'للجنة نهار الاخرة': 21853,
#  'نهار الاخرة وتشوفي': 25752,
#  'الاخرة وتشوفي ربي': 2228,
#  'وتشوفي ربي سبحانو': 27389,
#  'ربي سبحانو يعلقها': 15343,
#  'سبحانو يعلقها الاثداء': 16330,
#  'يعلقها الاثداء نتاعها': 30215,
#  'الاثداء نتاعها وراتهم': 2177,
#  'نتاعها وراتهم للناس': 24968,
#  'وراتهم للناس راكي': 27721,
#  'للناس راكي دافعي': 22003,
#  'راكي دافعي العاهرات': 15188,
#  'دافعي العاهرات باينة': 14506,
#  'العاهرات باينة كيفكيف': 5231,
#  'باينة كيفكيف ثعلب': 8852,
#  'كيفكيف ثعلب الصحراء': 20996,
#  'عاشت تونس حره': 18034,
#  'تونس حره علمانية': 12267,
#  'الليبيين نفسهم معرضين': 6439,
#  'نفسهم معرضين للقتل': 25561,
#  'معرضين للقتل والسرقة': 24008,
#  'للقتل والسرقة والخطف': 21956,
#  'والسرقة والخطف والسطو': 26773,
#  'والخطف والسطو لحظه': 26712,
#  'والسطو لحظه البلاد': 26775,
#  'لحظه البلاد تعيش': 21323,
#  'البلاد تعيش حرب': 2685,
#  'تعيش حرب اهلية': 11402,
#  'حرب اهلية قوات': 13512,
#  'اهلية قوات الناتو': 8165,
#  'قوات الناتو دمرت': 20286,
#  'الناتو دمرت المنظومه': 7345,
#  'دمرت المنظومه العسكرية': 14669,
#  'المنظومه العسكرية والامنية': 7201,
#  'العسكرية والامنية بالتعاون': 5416,
#  'والامنية بالتعاون العملاء': 26617,
#  'بالتعاون العملاء وتخلت': 8470,
#  'العملاء وتخلت اكمال': 5542,
#  'وتخلت اكمال مشروعها': 27348,
#  'اكمال مشروعها التدميري': 1823,
#  'مية بر اعطي': 24749,
#  'بر اعطي طراحة': 9026,
#  'اعطي طراحة إلبخرتك': 1597,
#  'طراحة إلبخرتك اتنة': 17815,
#  'إلبخرتك اتنة ناتنة': 724,
#  'اتنة ناتنة لاحدة': 940,
#  'ناتنة لاحدة ماتجي': 24832,
#  'لاحدة ماتجي حتشي': 21077,
#  'ماتجي حتشي متشبهي': 22287,
#  'حتشي متشبهي إلحت': 13403,
#  'متشبهي إلحت شئ': 22880,
#  'إلحت شئ وبالنسبة': 726,
#  'شئ وبالنسبة لكريم': 16688,
#  'وبالنسبة لكريم الغربي': 27234,
#  'لكريم الغربي سيدك': 21759,
#  'الغربي سيدك نعطيه': 5650,
#  'سيدك نعطيه لايك': 16629,
#  'نعطيه لايك رجل': 25492,
#  'لايك رجل بأتم': 21195,
#  'رجل بأتم معنا': 15553,
#  'بأتم معنا الكلمة': 8295,
#  'معنا الكلمة ماهوش': 24075,
#  'الكلمة ماهوش هامل': 6319,
#  'ماهوش هامل سلهوبة': 22539,
#  'هامل سلهوبة يال': 25970,
#  'سلهوبة يال جاي': 16501,
#  'يال جاي مل': 29076,
#  'جاي مل هنتيتي': 12819,
#  'مل هنتيتي تتكل': 24317,
#  'هنتيتي تتكل مي': 26137,
#  'تتكل مي بلقا': 10292,
#  'جزائري معناها نحب': 12966,
#  'معناها نحب تونس': 24098,
#  'نحب تونس معناها': 25058,
#  'تونس معناها جزائري': 12417,
#  'معناها جزائري معناها': 24084,
#  'جزائري معناها خاوة': 12965,
#  'معناها خاوة خاوة': 24086,
#  'خاوة خاوة معناها': 14067,
#  'خاوة معناها جيران': 14068,
#  'معناها جيران معناها': 24085,
#  'جيران معناها معناها': 13194,
#  'معناها معناها معناها': 24096,
#  'معناها معناها ربي': 24095,
#  'معناها ربي يهدينا': 24087,
#  'ربي يهدينا شاء': 15470,
#  'يهدينا شاء معناها': 30727,
#  'ياجزائريين قاطعوا تونس': 28960,
#  'قاطعوا تونس لانريد': 19702,
#  'تونس لانريد تربيح': 12373,
#  'لانريد تربيح اليهود': 21150,
#  'جزائرية تزني أبوها': 12975,
#  'تزني أبوها تقول': 10900,
#  'أبوها تقول بابا': 45,
#  'تقول بابا حواني': 11654,
#  'عار خنار وماكش': 18012,
#  'خنار وماكش متربية': 14308,
#  'وماكش متربية قبيحة': 28486,
#  'متربية قبيحة النساء': 22859,
#  'قبيحة النساء مية': 19864,
#  'النساء مية يعطيك': 7482,
#  'مية يعطيك وهف': 24752,
#  'لطفي معلم ربي': 21566,
#  'معلم ربي يحفضك': 24056,
#  'ربي يحفضك وينور': 15415,
#  'يحفضك وينور طريقك': 29502,
#  'وينور طريقك الجزاءر': 28893,
#  'بحالك تانحويوهم بالتوبزة': 8929,
#  'تانحويوهم بالتوبزة بلمرض': 10105,
#  'بالتوبزة بلمرض تخبى': 8477,
#  'بلمرض تخبى ورا': 9724,
#  'تخبى ورا الحاسوب': 10669,
#  'ورا الحاسوب نيكي': 27709,
#  'الحاسوب نيكي موك': 3402,
#  'نيكي موك القحبة': 25884,
#  'موك القحبة سول': 24702,
#  'القحبة سول جداتك': 5968,
#  'سول جداتك القحبة': 16585,
#  'جداتك القحبة جدك': 12898,
#  'القحبة جدك المرض': 5958,
#  'التوانسة ولاد بورقيبة': 2990,
#  'ولاد بورقيبة وخواتاتهم': 28242,
#  'بورقيبة وخواتاتهم القحاب': 9912,
#  'خسارة تونس تعيش': 14164,
#  'تونس تعيش قحبه': 12251,
#  'ضاهرة وجهها صوتها': 17688,
#  'وجهها صوتها قحبة': 27555,
#  'صوتها قحبة مالبريمة': 17639,
#  'قحبة مالبريمة القحاب': 19951,
#  'مالبريمة القحاب عمرهم': 22472,
#  'القحاب عمرهم يكونو': 5918,
#  'عمرهم يكونو نضاف': 18659,
#  'يكونو نضاف شريفات': 30487,
#  'يطياح تحمي غالب': 30070,
#  'تحمي غالب والله': 10606,
#  'غالب والله سيدي': 18934,
#  'والله سيدي رجال': 26970,
#  'سيدي رجال شمس': 16637,
#  'رجال شمس والله': 15513,
#  'شمس والله عيب': 17152,
#  'والله عيب خويا': 26984,
#  'عيب خويا لطفي': 18886,
#  'خويا لطفي تقول': 14375,
#  'لطفي تقول هكدك': 21500,
#  'تقول هكدك كلام': 11681,
#  'هكدك كلام يقلوه': 26103,
#  'كلام يقلوه الرجال': 20778,
#  'يقلوه الرجال والله': 30409,
#  'الرجال والله نحترمك': 4244,
#  'والله نحترمك قللت': 27024,
#  'نحترمك قللت احترام': 25114,
#  'قللت احترام شمس': 20197,
#  'احترام شمس عيب': 989,
#  'راجل كبير وميبون': 15096,
#  'يعرض الباجي قايد': 30125,
#  'الباجي قايد السبسي': 2585,
#  'قايد السبسي طبيب': 19838,
#  'السبسي طبيب المخ': 4529,
#  'طبيب المخ الأعصاب': 17793,
#  'المخ الأعصاب الأطباء': 6582,
#  'الأعصاب الأطباء الاختصاصات': 1935,
#  'الأطباء الاختصاصات ستجدون': 1928,
#  'الاختصاصات ستجدون فاقد': 2216,
#  'ستجدون فاقد لجميع': 16352,
#  'فاقد لجميع الصلوحيات': 19123,
#  'لجميع الصلوحيات بالتالي': 21298,
#  'الصلوحيات بالتالي لابد': 5044,
#  'بالتالي لابد الحجر': 8462,
#  'لابد الحجر ممتلكاته': 21048,
#  'الحجر ممتلكاته إحالته': 3436,
#  'ممتلكاته إحالته فورا': 24406,
#  'إحالته فورا مستشفى': 639,
#  'فورا مستشفى المجانين': 19601,
#  'مستشفى المجانين عزله': 23606,
#  'المجانين عزله منصبه': 6539,
#  'تونس قحبة ولاميبون': 12351,
#  'قحبة ولاميبون نحي': 19968,
#  'ولاميبون نحي تصويرة': 28267,
#  'نحي تصويرة الطفلة': 25159,
#  'تصويرة الطفلة وعبر': 11112,
#  'الطفلة وعبر بوجهك': 5111,
#  'وعبر بوجهك خرى': 27998,
#  'بوجهك خرى عصبة': 9894,
#  'خرى عصبة ربك': 14149,
#  'عصبة ربك اسمك': 18409,
#  'ربك اسمك مرة': 15269,
#  'اسمك مرة لمياء': 1431,
#  'مرة لمياء مرة': 23362,
#  'لمياء مرة خرى': 22111,
#  'مرة خرى نحي': 23357,
#  'خرى نحي تصويرة': 14150,
#  'تصويرة الطفلة وحط': 11111,
#  'الطفلة وحط صرمك': 5110,
#  'وحط صرمك ولاقبتك': 27623,
#  'صرمك ولاقبتك وسب': 17505,
#  'ممكن اشتراك القناة': 24421,
#  'اشتراك القناة إخواني': 1467,
#  'كامل الضجة اضن': 20428,
#  'الضجة اضن المستحيل': 5072,
#  'اضن المستحيل يفطر': 1539,
#  'المستحيل يفطر مسلم': 6828,
#  'يفطر مسلم رمضان': 30316,
#  'مسلم رمضان وهؤلاء': 23716,
#  'رمضان وهؤلاء ملحدين': 15768,
#  'وهؤلاء ملحدين ديانات': 28709,
#  'ملحدين ديانات تانية': 24353,
#  'ديانات تانية ومصيرهم': 14805,
#  'تانية ومصيرهم جهنم': 10109,
#  'ومصيرهم جهنم خالدون': 28565,
#  'جهنم خالدون دينكم': 13125,
#  'خالدون دينكم ولي': 14034,
#  'دينكم ولي دين': 14897,
#  'ولي دين يسهل': 28433,
#  'دين يسهل بدل': 14875,
#  'يسهل بدل الجدال': 29935,
#  'بدل الجدال هدا': 8986,
#  'الجدال هدا يجب': 3183,
#  'هدا يجب الاهتمام': 26030,
#  'يجب الاهتمام بالأخلاق': 29333,
#  'الاهتمام بالأخلاق والتربية': 2545,
#  'بالأخلاق والتربية أحسن': 8433,
#  'تحية لقحاب تونس': 10645,
#  'خلك الاحترام والضعافه': 14262,
#  'الاحترام والضعافه اليهود': 2204,
#  'والضعافه اليهود كمسلم': 26817,
#  'اليهود كمسلم اكون': 7780,
#  'كمسلم اكون جبان': 20923,
#  'اكون جبان ليهودي': 1826,
#  'تاكل روحك اااخويا': 10090,
#  'روحك اااخويا تبالك': 15829,
#  'اااخويا تبالك محترمة': 782,
#  'تبالك محترمة دافع': 10119,
#  'محترمة دافع خويا': 23098,
#  'دافع خويا مدي': 14502,
#  'خويا مدي تونسية': 14377,
#  'مدي تونسية متربية': 23295,
#  'تونسية متربية مجمعناش': 12586,
#  'العبو العبو لعنة': 5284,
#  'العبو لعنة كانهم': 5285,
#  'لعنة كانهم ليسو': 21658,
#  'كانهم ليسو مجاورين': 20461,
#  'ليسو مجاورين الجزائر': 22209,
#  'مجاورين الجزائر والله': 23030,
#  'الجزائر والله تجرا': 3248,
#  'والله تجرا وفعلها': 26929,
#  'تجرا وفعلها امامي': 10350,
#  'وفعلها امامي هكدا': 28085,
#  'امامي هكدا لقتلته': 7820,
#  'هكدا لقتلته انتهاك': 26102,
#  'لقتلته انتهاك شهر': 21718,
#  'انتهاك شهر رمضان': 8014,
#  'تسلم يالغالي يحفظك': 10984,
#  'يالغالي يحفظك العلالي': 29087,
#  'يحفظك العلالي شاء': 29506,
#  'ايطير طيران بشير': 8268,
#  'طيران بشير براا': 17936,
#  'بشير براا قعادت': 9268,
#  'براا قعادت تنافق': 9060,
#  'قعادت تنافق وموش': 20137,
#  'تنافق وموش عجبك': 11891,
#  'هههه ملخر مومو': 26177,
#  'ملخر مومو يفلم': 24356,
#  'مومو يفلم يعطي': 24714,
#  'يفلم يعطي عندوش': 30336,
#  'يعطي عندوش فلوس': 30184,
#  'الراجل يصرف يدي': 4187,
#  'يصرف يدي بصح': 29990,
#  'يدي بصح درك': 29714,
#  'بصح درك لمراء': 9328,
#  'درك لمراء أخت': 14584,
#  'لمراء أخت زوجة': 22077,
#  'أخت زوجة تصرف': 113,
#  'زوجة تصرف تعاون': 16154,
#  'تصرف تعاون بالنص': 11090,
#  'تعاون بالنص تاخد': 11205,
#  'بالنص تاخد نص': 8766,
#  'تاخد نص الميراث': 10031,
#  'نص الميراث تاخد': 25361,
#  'الميراث تاخد الثلث': 7306,
#  'تاخد الثلث تصرفش': 10030,
#  'الثلث تصرفش تخبيه': 3142,
#  'تصرفش تخبيه الرجل': 11096,
#  'تخبيه الرجل مسؤول': 10671,
#  'الرجل مسؤول الدار': 4296,
#  'مسؤول الدار زوج': 23550,
#  'الدار زوج اب': 3814,
#  'زوج اب اخ': 16146,
#  'اب اخ ابن': 795,
#  'اخ ابن يصرف': 1082,
#  'ابن يصرف الميراث': 837,
#  'يصرف الميراث داه': 29989,
#  'الميراث داه لمراء': 7312,
#  'داه لمراء تدي': 14511,
#  'لمراء تدي اقل': 22079,
#  'تدي اقل تصرف': 10762,
#  'قولي لاخر قحبة': 20331,
#  'لاخر قحبة بتصريح': 21094,
#  'قحبة بتصريح دولي': 19930,
#  'بتصريح دولي وريحي': 8888,
#  'دولي وريحي راسنا': 14788,
#  'وريحي راسنا تحيه': 27781,
#  'راسنا تحيه لشعب': 15162,
#  'تحيه لشعب تونسي': 10658,
#  'لشعب تونسي شريف': 21435,
#  'تونسي شريف جزائريه': 12536,
#  'شريف جزائريه والله': 16890,
#  'جزائريه والله تونس': 12983,
#  'والله تونس ضاعت': 26944,
#  'تونس ضاعت دين': 12321,
#  'ضاعت دين خوف': 17677,
#  'دين خوف ربي': 14852,
#  'خوف ربي رحم': 14348,
#  'ربي رحم ربي': 15334,
#  'زايدة الأعباد شانوا': 15985,
#  'خامجةربي ينتقم اعلام': 14056,
#  'ينتقم اعلام العار': 30613,
#  'تونس منظر شوف': 12425,
#  'منظر شوف الشعر': 24532,
#  'شوف الشعر مزال': 17219,
#  'الشعر مزال بالي': 4904,
#  'مزال بالي موظه': 23521,
#  'بالي موظه هاكي': 8789,
#  'موظه هاكي الكرش': 24692,
#  'هاكي الكرش هاذا': 25951,
#  'الكرش هاذا جاهل': 6221,
#  'هاذا جاهل كريم': 25925,
#  'جاهل كريم الغربي': 12782,
#  'كريم الغربي ينقد': 20647,
#  'الغربي ينقد حده': 5655,
#  'ينقد حده مثقفه': 30673,
#  'حده مثقفه مره': 13431,
#  'الجزائر امراة تعيفففففففف': 3211,
#  'امراة تعيفففففففف روحي': 7863,
#  'تعيفففففففف روحي دري': 11411,
#  'روحي دري حجاب': 15919,
#  'دري حجاب وجه': 14586,
#  'حجاب وجه بحس': 13416,
#  'وجه بحس الردائة': 27525,
#  'بحس الردائة بأم': 8948,
#  'الردائة بأم عينها': 4345,
#  'أعداء الإسلام الکفرة': 302,
#  'الإسلام الکفرة هكذا': 2050,
#  'الکفرة هكذا تقهر': 7806,
#  'هكذا تقهر اعداء': 26107,
#  'تقهر اعداء الاسلام': 11638,
#  'اعداء الاسلام بمستوى': 1571,
#  'الاسلام بمستوى الاخلاق': 2311,
#  'بمستوى الاخلاق المنحط': 9751,
#  'الاخلاق المنحط السب': 2234,
#  'المنحط السب الشتم': 7179,
#  'السب الشتم الومك': 4510,
#  'الشتم الومك فانت': 4763,
#  'الومك فانت تتبع': 7720,
#  'فانت تتبع دين': 19179,
#  'تتبع دين الارهاب': 10203,
#  'دين الارهاب النكاح': 14838,
#  'الارهاب النكاح نطفة': 2262,
#  'النكاح نطفة اسلامية': 7545,
#  'نطفة اسلامية وسخة': 25420,
#  'يعطييك غلبااا مريم': 30210,
#  'غلبااا مريم فضحت': 19003,
#  'مريم فضحت روحك': 23500,
#  'فضحت روحك ياااا': 19391,
#  'روحك ياااا تييييت': 15867,
#  'ياااا تييييت رابي': 28930,
#  'تييييت رابي هااااامله': 12626,
#  'رابي هااااامله يحباني': 15057,
#  'هااااامله يحباني فماا': 25890,
#  'يحباني فماا هكااا': 29427,
#  'فماا هكااا ربي': 19518,
#  'هكااا ربي نسدق': 26097,
#  'احترماتي ولافتخار والاعتزازات': 1001,
#  'ولافتخار والاعتزازات لاخت': 28254,
#  'والاعتزازات لاخت مايا': 26602,
#  'لاخت مايا مثقفة': 21090,
#  'مايا مثقفة دكية': 22627,
#  'مثقفة دكية والشخص': 22977,
#  'دكية والشخص مستواه': 14649,
#  'والشخص مستواه ضعيفة': 26799,
#  'مستواه ضعيفة للنقاش': 23630,
#  'ضعيفة للنقاش متعصب': 17732,
#  'للنقاش متعصب لاخت': 22007,
#  'متعصب لاخت مايا': 22908,
#  'لاخت مايا اتابعوها': 21089,
#  'مايا اتابعوها هداخلاتها': 22555,
#  'اتابعوها هداخلاتها تفرح': 873,
#  'هداخلاتها تفرح القلب': 26031,
#  'تفرح القلب وملمومة': 11472,
#  'القلب وملمومة بلمعلومات': 6107,
#  'وملمومة بلمعلومات سياسيا': 28583,
#  'بلمعلومات سياسيا وثقافيا': 9725,
#  'سياسيا وثقافيا المستوات': 16612,
#  'وثقافيا المستوات اخوك': 27471,
#  'المستوات اخوك المغرب': 6845,
#  'اخوك المغرب اتابع': 1183,
#  'المغرب اتابع حوراتك': 7058,
#  'اتابع حوراتك مزيدا': 872,
#  'حوراتك مزيدا كره': 13908,
#  'مزيدا كره كره': 23542,
#  'كره كره واحب': 20624,
#  'كره واحب احب': 20626,
#  'واحب احب يعاونك': 26456,
#  'احب يعاونك لاعداء': 982,
#  'يعاونك لاعداء والحساد': 30087,
#  'شعب جاهل يفهم': 16945,
#  'جاهل يفهم ويعرف': 12793,
#  'يفهم ويعرف دينه': 30339,
#  'ويعرف دينه شئ': 28847,
#  'اله محمد رسول': 7579,
#  'محمد رسول بالله': 23162,
#  'رسول بالله بلاد': 15651,
#  'بالله بلاد ولت': 8681,
#  'بلاد ولت حسبنا': 9569,
#  'ولت حسبنا الوكيل': 28279,
#  'ويرحم والدين ضربها': 28819,
#  'والدين ضربها نحبش': 26743,
#  'ضربها نحبش الشماته': 17716,
#  'نحبش الشماته العنف': 25077,
#  'الشماته العنف تستاهل': 4926,
#  'العنف تستاهل كفوف': 5560,
#  'تستاهل كفوف العاقبه': 10937,
#  'كفوف العاقبه للعين': 20716,
#  'العاقبه للعين لخري': 5172,
#  'قنبلة شواذ لتقدم': 20277,
#  'شواذ لتقدم لزم': 17202,
#  'لتقدم لزم ندعم': 21264,
#  'لزم ندعم شذوذ': 21399,
#  'ندعم شذوذ ياحيوانات': 25188,
#  'شذوذ ياحيوانات اوحثالات': 16828,
#  'ياحيوانات اوحثالات كميائية': 28969,
#  'اوحثالات كميائية بهايم': 8178,
#  'بيع تليفونك وبرا': 9989,
#  'تليفونك وبرا صلح': 11816,
#  'وبرا صلح مراياتك': 27247,
#  'صلح مراياتك ويزي': 17575,
#  'مراياتك ويزي مالتسول': 23343,
#  'ويزي مالتسول عمرك': 28828,
#  'يهودي مخربي احذرو': 30781,
#  'يذلك ياكلب القانون': 29729,
#  'ياكلب القانون الأعلى': 29068,
#  'القانون الأعلى القرآن': 5872,
#  'الأعلى القرآن الكريم': 1937,
#  'القرآن الكريم دستورك': 6021,
#  'الكريم دستورك كلب': 6233,
#  'بالل اهی نسألک': 8654,
#  'اهی نسألک یا': 8173,
#  'نسألک یا إبن': 25244,
#  'یا إبن الجواری': 30888,
#  'إبن الجواری الس': 629,
#  'الجواری الس بایا': 3382,
#  'الس بایا تحب': 4486,
#  'بایا تحب ترکبلها': 8856,
#  'تحب ترکبلها زب': 10411,
#  'ترکبلها زب فقت': 10897,
#  'زب فقت إل': 15993,
#  'فقت إل بوک': 19442,
#  'إل بوک میبون': 721,
#  'بوک میبون یلعبها': 9958,
#  'میبون یلعبها مل': 24823,
#  'یلعبها مل تکرکیره': 30898,
#  'ههههههههه اوموا مرض': 26268,
#  'اوموا مرض الكوليرا': 8229,
#  'مرض الكوليرا نتا': 23414,
#  'الكوليرا نتا ختك': 6338,
#  'نتا ختك يماك': 24956,
#  'ختك يماك هوما': 14096,
#  'يماك هوما الكوليرا': 30543,
#  'هوما الكوليرا تبا': 26326,
#  'الكوليرا تبا التوانسة': 6336,
#  'تبا التوانسة الجيعانين': 10113,
#  'التوانسة الجيعانين اشبعو': 2960,
#  'الجيعانين اشبعو ماكلة': 3388,
#  'اشبعو ماكلة ممبعد': 1465,
#  'ماكلة ممبعد احكو': 22457,
#  'ممبعد احكو الورث': 24404,
#  'ههههه لبنات يدافعو': 26201,
#  'لبنات يدافعو شمس': 21232,
#  'غريبة والله أفارقة': 18986,
#  'والله أفارقة ننتموا': 26906,
#  'أفارقة ننتموا للقارة': 338,
#  'ننتموا للقارة الإفريقية': 25743,
#  'للقارة الإفريقية معناتها': 21954,
#  'الإفريقية معناتها أصلنا': 2136,
#  'معناتها أصلنا سمر': 24076,
#  'أصلنا سمر وحادثة': 274,
#  'سمر وحادثة السفير': 16514,
#  'وحادثة السفير تنجم': 27581,
#  'السفير تنجم عنصرية': 4581,
#  'تنجم عنصرية أساس': 11922,
#  'عنصرية أساس أحنا': 18745,
#  'أساس أحنا البيض': 216,
#  'أحنا البيض متقتلش': 104,
#  'البيض متقتلش منا': 2767,
#  'المستوي الشخصي شمس': 6856,
#  'الشخصي شمس افضل': 4772,
#  'نشهد الاجراء تقريبا': 25343,
#  'الاجراء تقريبا تقوم': 2193,
#  'تقريبا تقوم زنديق': 11607,
#  'تقوم زنديق مجرمي': 11701,
#  'زنديق مجرمي إمارات': 16121,
#  'مجرمي إمارات تونس': 23049,
#  'نزل الستار أعينكم': 25226,
#  'الستار أعينكم والحمد': 4537,
#  'أعينكم والحمد لله': 328,
#  'والحمد لله الآن': 26705,
#  'لله الآن تعلمون': 22008,
#  'الآن تعلمون يحكمكم': 1846,
#  'تعلمون يحكمكم وبالآحرى': 11348,
#  'يحكمكم وبالآحرى يستعبدكم': 29523,
#  'وبالآحرى يستعبدكم قوموا': 27227,
#  'يستعبدكم قوموا وأعيدوا': 29890,
#  'قوموا وأعيدوا أمجادكم': 20341,
#  'وأعيدوا أمجادكم رب': 26390,
#  'أمجادكم رب العز': 448,
#  'رب العز خير': 15248,
#  'العز خير أخرجت': 5407,
#  'خير أخرجت للن': 14388,
#  'أخرجت للن اس': 132,
#  'تعايش اليهود وماناش': 11209,
#  'اليهود وماناش اصحاب': 7787,
#  'ربي يقدر الخير': 15442,
#  'يقدر الخير تونس': 30371,
#  'الخير تونس راهي': 3800,
#  'تونس راهي تناكت': 12296,
#  'راهي تناكت راحت': 15198,
#  'تناكت راحت للواد': 11901,
#  'تفووووو وعلي أمك': 11559,
#  'وشنو مشر وبات': 27907,
#  'مشر وبات بهلوانية': 23835,
#  'ثمه شر عداوه': 12679,
#  'شر عداوه للإسلام': 16833,
#  'عداوه للإسلام الرهوط': 18247,
#  'للإسلام الرهوط عباد': 21793,
#  'الرهوط عباد فيقو': 4379,
#  'عباد فيقو رواحكم': 18158,
#  'فيقو رواحكم ربي': 19643,
#  'رواحكم ربي يعذب': 15793,
#  'ربي يعذب مزال': 15431,
#  'يعذب مزال مزال': 30119,
#  'مزال مزال يحللولكم': 23523,
#  'مزال يحللولكم الجنه': 23524,
#  'يحللولكم الجنه ذراع': 29563,
#  'الجنه ذراع الرسمي': 3348,
#  'ذراع الرسمي يجيبو': 14955,
#  'الرسمي يجيبو ربي': 4351,
#  'يجيبو ربي الفلوس': 29392,
#  'ربي الفلوس عبات': 15300,
#  'الفلوس عبات كروشهم': 5818,
#  'عبات كروشهم ناس': 18150,
#  'كروشهم ناس الفقر': 20635,
#  'ناس الفقر ماكلهم': 24856,
#  'الفقر ماكلهم زعام': 5791,
#  'ماكلهم زعام المسوات': 22458,
#  'زعام المسوات الحريات': 16064,
#  'المسوات الحريات يعنبو': 6941,
#  'الحريات يعنبو المسوات': 3494,
#  'يعنبو المسوات الحريه': 30252,
#  'المسوات الحريه فقر': 6942,
#  'الحريه فقر سرقه': 3508,
#  'فقر سرقه فيقو': 19443,
#  'سرقه فيقو عباد': 16401,
#  'فيقو عباد يلهيو': 19645,
#  'عباد يلهيو يسكتو': 18165,
#  'يلهيو يسكتو الرسمي': 30534,
#  'يسكتو الرسمي المخبي': 29914,
#  'يكفرو يهدرو بكلام': 30469,
#  'يهدرو بكلام فاحش': 30706,
#  'بكلام فاحش قاعدين': 9498,
#  'فاحش قاعدين ديار': 19076,
#  'قاعدين ديار يديرو': 19723,
#  'ديار يديرو فيديوات': 14801,
#  'يديرو فيديوات يزعف': 29721,
#  'فيديوات يزعف يروح': 19630,
#  'يزعف يروح يدير': 29818,
#  'يروح يدير فيديو': 29794,
#  'يدير فيديو تكفر': 29717,
#  'فيديو تكفر تسمي': 19621,
#  'تكفر تسمي روحك': 11737,
#  'تسمي روحك راجل': 10990,
#  'روحك راجل قحاب': 15841,
#  'راجل قحاب مكش': 15093,
#  'قحاب مكش راجل': 19910,
#  'تونس تعمل مزية': 12250,
#  'تعمل مزية نحى': 11372,
#  'مزية نحى اسم': 23541,
#  'نحى اسم تونس': 25156,
#  'اسم تونس اسمك': 1413,
#  'باقي الرجل شني': 8424,
#  'الرجل شني حكايتها': 4284,
#  'شني حكايتها شتحب': 17179,
#  'حكايتها شتحب شكونه': 13784,
#  'شتحب شكونه للا': 16775,
#  'شكونه للا مريم': 17068,
#  'للا مريم اسمع': 21798,
#  'مريم اسمع فلت': 23458,
#  'اسمع فلت يقولوا': 1425,
#  'علاقة للتحرش باللباس': 18539,
#  'للتحرش باللباس الدول': 21838,
#  'باللباس الدول لتي': 8656,
#  'الدول لتي تبيح': 3965,
#  'لتي تبيح الحرية': 21290,
#  'تبيح الحرية الجنسية': 10188,
#  'الحرية الجنسية تحرش': 3496,
#  'الجنسية تحرش يراد': 3340,
#  'تحرش يراد تسريفه': 10477,
#  'يراد تسريفه طرف': 29733,
#  'تسريفه طرف وسائل': 10973,
#  'طرف وسائل الاعلام': 17827,
#  'وسائل الاعلام العاهرة': 27809,
#  'الاعلام العاهرة الحقيقة': 2422,
#  'العاهرة الحقيقة فوجود': 5239,
#  'الحقيقة فوجود التحرش': 3581,
#  'فوجود التحرش الحديث': 19597,
#  'التحرش الحديث الدول': 2810,
#  'الحديث الدول تقبل': 3453,
#  'الدول تقبل بممارسة': 3964,
#  'تقبل بممارسة الجنس': 11581,
#  'بممارسة الجنس وفق': 9765,
#  'الجنس وفق الاطر': 3333,
#  'وفق الاطر الشرعية': 28086,
#  'الاطر الشرعية فظهور': 2408,
#  'الشرعية فظهور الحديث': 4793,
#  'فظهور الحديث التحرش': 19411,
#  'الحديث التحرش ظاهرة': 3452,
#  'التحرش ظاهرة صحية': 2813,
#  'ظاهرة صحية تؤكذ': 17947,
#  'صحية تؤكذ سلامة': 17393,
#  'تؤكذ سلامة المجتمع': 10017,
#  'سلامة المجتمع الامراض': 16458,
#  'المجتمع الامراض الاجتماعية': 6546,
#  'الامراض الاجتماعية رأسها': 2503,
#  'الاجتماعية رأسها الزنا': 2190,
#  'رأسها الزنا الخنا': 14997,
#  'الزنا الخنا عكس': 4435,
#  'الخنا عكس الدول': 3782,
#  'عكس الدول تدعم': 18515,
#  'الدول تدعم الانفتاح': 3962,
#  'تدعم الانفتاح التحرر': 10747,
#  'الانفتاح التحرر الجنسي': 2539,
#  'التحرر الجنسي مجال': 2808,
#  'الجنسي مجال للحديث': 3337,
#  'مجال للحديث موضوع': 23020,
#  'للحديث موضوع التحرش': 21857,
#  'موضوع التحرش الزنا': 24685,
#  'التحرش الزنا متاح': 2811,
#  'الزنا متاح المباشرة': 4438,
#  'متاح المباشرة الجنسية': 22733,
#  'المباشرة الجنسية متاحة': 6481,
#  'الجنسية متاحة فلماذا': 3342,
#  'متاحة فلماذا يطرح': 22734,
#  'فلماذا يطرح موضوع': 19502,
#  'يطرح موضوع التحرش': 30050,
#  'موضوع التحرش قالتحرش': 24686,
#  'التحرش قالتحرش يطرح': 2814,
#  'قالتحرش يطرح مواجهة': 19755,
#  'يطرح مواجهة مجتمعية': 30049,
#  'مواجهة مجتمعية للزنا': 24620,
#  'مجتمعية للزنا العلاقات': 23034,
#  'للزنا العلاقات المحرمة': 21896,
#  'العلاقات المحرمة يؤدي': 5475,
#  'المحرمة يؤدي بذوي': 6576,
#  ...}

# %%
df['aggressive'] = df['type'].apply(lambda x: 1 if x =='aggressive' else  0)
df.head()
# Out:
#                                              comment        type  aggressive
# 0                                       يعطيكم الصحة      normal           0
# 1                                    عشي عندهما رجال      normal           0
# 2                         نبيك مغتصب الاطفال المنيوك  aggressive           1
# 3  بشير فار حبس خارج ثالثة ابتيدائي جاي اتناقش ما...      normal           0
# 4  مول القناة دزيزي جنيت تفرجت الفديو تاعك ولدي ت...      normal           0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.comment,df.aggressive,test_size=0.2)

# %%
print("Shape of X_train: ", X_train.shape)
print("Shape of X_test: ", X_test.shape)
# Out:
# Shape of X_train:  (3524,)
# Shape of X_test:  (882,)

# %%
X_train.head()
# Out:
# 4300                          بسلفي السلفية براء
# 1611            لطفي متكبر حاسب روحك وجه السنفور
# 4121                        عبير موسى قحبةالنضام
# 3061                      الموت للاخوان المسلمين
# 1735    والله شعب جاهل خليتو الدين تبعوا الدستور
# Name: comment, dtype: object

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline 
from sklearn.metrics import classification_report

clf = Pipeline ([
    ('vectorizer_bow', CountVectorizer()),
    ('Multi NB', MultinomialNB())
])

clf.fit(X_train, y_train)

y_pred = clf.predict (X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84       462
#            1       0.80      0.89      0.84       420
#
#     accuracy                           0.84       882
#    macro avg       0.84      0.84      0.84       882
# weighted avg       0.85      0.84      0.84       882

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline 
from sklearn.metrics import classification_report

clf = Pipeline ([
    ('vectorizer_bow', CountVectorizer(ngram_range = (2, 2))),
    ('Multi NB', MultinomialNB())
])

clf.fit(X_train, y_train)

y_pred = clf.predict (X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.51      0.64       462
#            1       0.63      0.92      0.75       420
#
#     accuracy                           0.71       882
#    macro avg       0.76      0.72      0.70       882
# weighted avg       0.76      0.71      0.69       882

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline 
from sklearn.metrics import classification_report

clf = Pipeline ([
    ('vectorizer_bow', CountVectorizer(ngram_range = (3, 3))),
    ('Multi NB', MultinomialNB())
])

clf.fit(X_train, y_train)

y_pred = clf.predict (X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.36      0.53       462
#            1       0.59      1.00      0.74       420
#
#     accuracy                           0.67       882
#    macro avg       0.79      0.68      0.64       882
# weighted avg       0.80      0.67      0.63       882

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline 
from sklearn.metrics import classification_report

clf = Pipeline ([
    ('vectorizer_bow', CountVectorizer(ngram_range = (1, 3))),
    ('Multi NB', MultinomialNB())
])

clf.fit(X_train, y_train)

y_pred = clf.predict (X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86       462
#            1       0.82      0.90      0.85       420
#
#     accuracy                           0.85       882
#    macro avg       0.86      0.86      0.85       882
# weighted avg       0.86      0.85      0.85       882
